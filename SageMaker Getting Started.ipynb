# %%
from sagemaker import get_execution_role

role = get_execution_role()
bucket='sagemaker-XXXXXXXXXXXXXXXX'

# %%
# %%time
import pickle, gzip, numpy, urllib.request, json

# Load the dataset
urllib.request.urlretrieve("http://deeplearning.net/data/mnist/mnist.pkl.gz", "mnist.pkl.gz")
with gzip.open('mnist.pkl.gz', 'rb') as f:
    train_set, valid_set, test_set = pickle.load(f, encoding='latin1')
# Out:
# CPU times: user 916 ms, sys: 288 ms, total: 1.2 s
# Wall time: 8.99 s

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (2,10)


def show_digit(img, caption='', subplot=None):
    if subplot == None:
        _, (subplot) = plt.subplots(1,1)
    imgr = img.reshape((28,28))
    subplot.axis('off')
    subplot.imshow(imgr, cmap='gray')
    plt.title(caption)

show_digit(train_set[0][30], 'This is a {}'.format(train_set[1][30]))

# %%
from sagemaker import KMeans

data_location = 's3://{}/kmeans_highlevel_example/data'.format(bucket)
output_location = 's3://{}/kmeans_example/output'.format(bucket)

print('training data will be uploaded to: {}'.format(data_location))
print('training artifacts will be uploaded to: {}'.format(output_location))

kmeans = KMeans(role=role,
                train_instance_count=2,
                train_instance_type='ml.c4.8xlarge',
                output_path=output_location,
                k=10,
                data_location=data_location)
# Out:
# training data will be uploaded to: s3://sagemaker-getting-started-cm-miyajima.yosuke/kmeans_highlevel_example/data
# training artifacts will be uploaded to: s3://sagemaker-getting-started-cm-miyajima.yosuke/kmeans_example/output

# %%
# %%time
kmeans.fit(kmeans.record_set(train_set[0]))
# Out:
# INFO:sagemaker:Creating training-job with name: kmeans-2018-07-04-03-38-47-265
# .....................
# Docker entrypoint called with argument(s): train
# [07/04/2018 03:42:11 INFO 139687520618304] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'_tuning_objective_metric': u'', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'_kvstore': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'true', u'epochs': u'1', u'init_method': u'random', u'local_lloyd_tol': u'0.0001', u'local_lloyd_max_iter': u'300', u'_disable_wait_to_read': u'false', u'extra_center_factor': u'auto', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'half_life_time_size': u'0', u'_num_slices': u'1'}
# [07/04/2018 03:42:11 INFO 139687520618304] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'784', u'k': u'10', u'force_dense': u'True'}
# [07/04/2018 03:42:11 INFO 139687520618304] Final configuration: {u'k': u'10', u'_tuning_objective_metric': u'', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'_kvstore': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'True', u'epochs': u'1', u'init_method': u'random', u'feature_dim': u'784', u'local_lloyd_tol': u'0.0001', u'local_lloyd_max_iter': u'300', u'_disable_wait_to_read': u'false', u'extra_center_factor': u'auto', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'half_life_time_size': u'0', u'_num_slices': u'1'}
# [07/04/2018 03:42:11 WARNING 139687520618304] Loggers have already been setup.
# [07/04/2018 03:42:12 INFO 139687520618304] Launching parameter server for role scheduler
# [07/04/2018 03:42:12 INFO 139687520618304] {'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'ethwe', 'SHLVL': '1', 'AWS_REGION': 'ap-northeast-1', 'NVIDIA_VISIBLE_DEVICES': 'all', 'TRAINING_JOB_NAME': 'kmeans-2018-07-04-03-38-47-265', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '18', 'HOSTNAME': 'aws', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/4741820b-bf16-4bec-b0e6-91b227898b96', 'PWD': '/'}
# [07/04/2018 03:42:12 INFO 139687520618304] envs={'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '2', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'ethwe', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.40.0.3', 'AWS_REGION': 'ap-northeast-1', 'NVIDIA_VISIBLE_DEVICES': 'all', 'TRAINING_JOB_NAME': 'kmeans-2018-07-04-03-38-47-265', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '18', 'HOSTNAME': 'aws', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/4741820b-bf16-4bec-b0e6-91b227898b96', 'DMLC_ROLE': 'scheduler', 'PWD': '/', 'DMLC_NUM_SERVER': '1'}
# [07/04/2018 03:42:12 INFO 139687520618304] Launching parameter server for role server
# [07/04/2018 03:42:12 INFO 139687520618304] {'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'ethwe', 'SHLVL': '1', 'AWS_REGION': 'ap-northeast-1', 'NVIDIA_VISIBLE_DEVICES': 'all', 'TRAINING_JOB_NAME': 'kmeans-2018-07-04-03-38-47-265', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '18', 'HOSTNAME': 'aws', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/4741820b-bf16-4bec-b0e6-91b227898b96', 'PWD': '/'}
# [07/04/2018 03:42:12 INFO 139687520618304] envs={'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '2', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'ethwe', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.40.0.3', 'AWS_REGION': 'ap-northeast-1', 'NVIDIA_VISIBLE_DEVICES': 'all', 'TRAINING_JOB_NAME': 'kmeans-2018-07-04-03-38-47-265', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '18', 'HOSTNAME': 'aws', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/4741820b-bf16-4bec-b0e6-91b227898b96', 'DMLC_ROLE': 'server', 'PWD': '/', 'DMLC_NUM_SERVER': '1'}
# [07/04/2018 03:42:12 INFO 139687520618304] Environment: {'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_WORKER': '2', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'ethwe', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.40.0.3', 'AWS_REGION': 'ap-northeast-1', 'NVIDIA_VISIBLE_DEVICES': 'all', 'TRAINING_JOB_NAME': 'kmeans-2018-07-04-03-38-47-265', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '18', 'HOSTNAME': 'aws', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/4741820b-bf16-4bec-b0e6-91b227898b96', 'DMLC_ROLE': 'worker', 'PWD': '/', 'DMLC_NUM_SERVER': '1'}
# [07/04/2018 03:42:12 INFO 139687520618304] Using default worker.
# [07/04/2018 03:42:12 INFO 139687520618304] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [07/04/2018 03:42:12 INFO 139687520618304] Create Store: dist_async
# Docker entrypoint called with argument(s): train
# [07/04/2018 03:42:11 INFO 140118425614144] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'_tuning_objective_metric': u'', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'_kvstore': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'true', u'epochs': u'1', u'init_method': u'random', u'local_lloyd_tol': u'0.0001', u'local_lloyd_max_iter': u'300', u'_disable_wait_to_read': u'false', u'extra_center_factor': u'auto', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'half_life_time_size': u'0', u'_num_slices': u'1'}
# [07/04/2018 03:42:11 INFO 140118425614144] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'784', u'k': u'10', u'force_dense': u'True'}
# [07/04/2018 03:42:11 INFO 140118425614144] Final configuration: {u'k': u'10', u'_tuning_objective_metric': u'', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'_kvstore': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'True', u'epochs': u'1', u'init_method': u'random', u'feature_dim': u'784', u'local_lloyd_tol': u'0.0001', u'local_lloyd_max_iter': u'300', u'_disable_wait_to_read': u'false', u'extra_center_factor': u'auto', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'half_life_time_size': u'0', u'_num_slices': u'1'}
# [07/04/2018 03:42:11 WARNING 140118425614144] Loggers have already been setup.
# [07/04/2018 03:42:12 INFO 140118425614144] Environment: {'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_WORKER': '2', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'ethwe', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.40.0.3', 'AWS_REGION': 'ap-northeast-1', 'NVIDIA_VISIBLE_DEVICES': 'all', 'TRAINING_JOB_NAME': 'kmeans-2018-07-04-03-38-47-265', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '18', 'HOSTNAME': 'aws', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/9f39e4cc-f000-4c2f-9a61-dc233e2f734f', 'DMLC_ROLE': 'worker', 'PWD': '/', 'DMLC_NUM_SERVER': '1'}
# [07/04/2018 03:42:12 INFO 140118425614144] Using default worker.
# [07/04/2018 03:42:12 INFO 140118425614144] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [07/04/2018 03:42:12 INFO 140118425614144] Create Store: dist_async
# [07/04/2018 03:42:13 INFO 140118425614144] nvidia-smi took: 0.0252001285553 secs to identify 0 gpus
# [07/04/2018 03:42:13 INFO 140118425614144] Number of GPUs being used: 0
# [07/04/2018 03:42:13 INFO 140118425614144] Setting up with params: {u'k': u'10', u'_tuning_objective_metric': u'', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'_kvstore': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'True', u'epochs': u'1', u'init_method': u'random', u'feature_dim': u'784', u'local_lloyd_tol': u'0.0001', u'local_lloyd_max_iter': u'300', u'_disable_wait_to_read': u'false', u'extra_center_factor': u'auto', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'half_life_time_size': u'0', u'_num_slices': u'1'}
# /opt/amazon/lib/python2.7/site-packages/ai_algorithms_sdk/config/config_helper.py:172: DeprecationWarning: deprecated
#   warnings.warn("deprecated", DeprecationWarning)
# /opt/amazon/lib/python2.7/site-packages/ai_algorithms_sdk/config/config_helper.py:122: DeprecationWarning: deprecated
#   warnings.warn("deprecated", DeprecationWarning)
# [07/04/2018 03:42:13 INFO 140118425614144] Number of GPUs being used: 0
# [07/04/2018 03:42:13 INFO 140118425614144] number of center slices 1
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Records Since Last Reset": {"count": 1, "max": 5000, "sum": 5000.0, "min": 5000}, "Total Batches Seen": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Total Records Seen": {"count": 1, "max": 5000, "sum": 5000.0, "min": 5000}, "Max Records Seen Between Resets": {"count": 1, "max": 5000, "sum": 5000.0, "min": 5000}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1530675733.749603, "Dimensions": {"Host": "algo-2", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1530675733.749572}
#
# [07/04/2018 03:42:13 INFO 139687520618304] nvidia-smi took: 0.0252060890198 secs to identify 0 gpus
# [07/04/2018 03:42:13 INFO 139687520618304] Number of GPUs being used: 0
# [07/04/2018 03:42:13 INFO 139687520618304] Setting up with params: {u'k': u'10', u'_tuning_objective_metric': u'', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'_kvstore': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'True', u'epochs': u'1', u'init_method': u'random', u'feature_dim': u'784', u'local_lloyd_tol': u'0.0001', u'local_lloyd_max_iter': u'300', u'_disable_wait_to_read': u'false', u'extra_center_factor': u'auto', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'half_life_time_size': u'0', u'_num_slices': u'1'}
# /opt/amazon/lib/python2.7/site-packages/ai_algorithms_sdk/config/config_helper.py:172: DeprecationWarning: deprecated
#   warnings.warn("deprecated", DeprecationWarning)
# /opt/amazon/lib/python2.7/site-packages/ai_algorithms_sdk/config/config_helper.py:122: DeprecationWarning: deprecated
#   warnings.warn("deprecated", DeprecationWarning)
# [07/04/2018 03:42:13 INFO 139687520618304] Number of GPUs being used: 0
# [07/04/2018 03:42:13 INFO 139687520618304] number of center slices 1
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Records Since Last Reset": {"count": 1, "max": 5000, "sum": 5000.0, "min": 5000}, "Total Batches Seen": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Total Records Seen": {"count": 1, "max": 5000, "sum": 5000.0, "min": 5000}, "Max Records Seen Between Resets": {"count": 1, "max": 5000, "sum": 5000.0, "min": 5000}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1530675733.755019, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1530675733.75499}
#
# [07/04/2018 03:42:14 INFO 139687520618304] processed a total of 25000 examples
# [07/04/2018 03:42:14 INFO 139687520618304] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 6, "sum": 6.0, "min": 6}, "Total Records Seen": {"count": 1, "max": 30000, "sum": 30000.0, "min": 30000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1530675734.053604, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 0}, "StartTime": 1530675733.75522}
#
# [07/04/2018 03:42:14 INFO 139687520618304] #throughput_metric: host=algo-1, train throughput=83751.8090997 records/second
# [07/04/2018 03:42:14 INFO 139687520618304] shrinking 100 centers into 10
# [07/04/2018 03:42:14 INFO 139687520618304] local kmeans attempt #0. Current mean square distance 10.503128
# [07/04/2018 03:42:14 INFO 139687520618304] local kmeans attempt #1. Current mean square distance 10.497890
# [07/04/2018 03:42:14 INFO 139687520618304] local kmeans attempt #2. Current mean square distance 10.983823
# [07/04/2018 03:42:14 INFO 139687520618304] local kmeans attempt #3. Current mean square distance 10.705312
# [07/04/2018 03:42:14 INFO 139687520618304] local kmeans attempt #4. Current mean square distance 10.908419
# [07/04/2018 03:42:14 INFO 139687520618304] local kmeans attempt #5. Current mean square distance 10.654412
# [07/04/2018 03:42:14 INFO 139687520618304] local kmeans attempt #6. Current mean square distance 10.216436
# [07/04/2018 03:42:14 INFO 139687520618304] local kmeans attempt #7. Current mean square distance 10.790646
# [07/04/2018 03:42:14 INFO 139687520618304] local kmeans attempt #8. Current mean square distance 9.939028
# [07/04/2018 03:42:14 INFO 139687520618304] local kmeans attempt #9. Current mean square distance 10.339899
# [07/04/2018 03:42:14 INFO 139687520618304] finished shrinking process. Mean Square Distance = 10
# [07/04/2018 03:42:14 INFO 139687520618304] #quality_metric: host=algo-1, train msd <loss>=9.93902778625
# [07/04/2018 03:42:14 INFO 139687520618304] batch data loading with context took: 61.7220%, (0.184129 secs)
# [07/04/2018 03:42:14 INFO 139687520618304] compute all data-center distances: point norm took: 10.9564%, (0.032685 secs)
# [07/04/2018 03:42:14 INFO 139687520618304] predict compute msd took: 8.6093%, (0.025683 secs)
# [07/04/2018 03:42:14 INFO 139687520618304] compute all data-center distances: inner product took: 7.0986%, (0.021177 secs)
# [07/04/2018 03:42:14 INFO 139687520618304] gradient: cluster center took: 5.3546%, (0.015974 secs)
# [07/04/2018 03:42:14 INFO 139687520618304] collect from kv store took: 2.1397%, (0.006383 secs)
# [07/04/2018 03:42:14 INFO 139687520618304] gradient: cluster size  took: 1.2216%, (0.003644 secs)
# [07/04/2018 03:42:14 INFO 139687520618304] splitting centers key-value pair took: 1.0200%, (0.003043 secs)
# [07/04/2018 03:42:14 INFO 139687520618304] gradient: one_hot took: 0.9008%, (0.002687 secs)
# [07/04/2018 03:42:14 INFO 139687520618304] update state and report convergance took: 0.4754%, (0.001418 secs)
# [07/04/2018 03:42:14 INFO 139687520618304] compute all data-center distances: center norm took: 0.3950%, (0.001178 secs)
# [07/04/2018 03:42:14 INFO 139687520618304] update set-up time took: 0.0664%, (0.000198 secs)
# [07/04/2018 03:42:14 INFO 139687520618304] predict minus dist took: 0.0403%, (0.000120 secs)
# [07/04/2018 03:42:14 INFO 139687520618304] TOTAL took: 0.298320055008
# [07/04/2018 03:42:14 INFO 139687520618304] Number of GPUs being used: 0
# #metrics {"Metrics": {"finalize.time": {"count": 1, "max": 309.19790267944336, "sum": 309.19790267944336, "min": 309.19790267944336}, "initialize.time": {"count": 1, "max": 15.513896942138672, "sum": 15.513896942138672, "min": 15.513896942138672}, "model.serialize.time": {"count": 1, "max": 0.19598007202148438, "sum": 0.19598007202148438, "min": 0.19598007202148438}, "update.time": {"count": 1, "max": 298.1870174407959, "sum": 298.1870174407959, "min": 298.1870174407959}, "epochs": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "state.serialize.time": {"count": 1, "max": 0.4839897155761719, "sum": 0.4839897155761719, "min": 0.4839897155761719}, "_shrink.time": {"count": 1, "max": 307.2521686553955, "sum": 307.2521686553955, "min": 307.2521686553955}}, "EndTime": 1530675734.40019, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1530675733.699677}
#
# [07/04/2018 03:42:14 INFO 139687520618304] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 2490.21315574646, "sum": 2490.21315574646, "min": 2490.21315574646}, "setuptime": {"count": 1, "max": 527.9250144958496, "sum": 527.9250144958496, "min": 527.9250144958496}}, "EndTime": 1530675734.403421, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1530675734.400298}
#
# [07/04/2018 03:42:14 INFO 140118425614144] processed a total of 25000 examples
# [07/04/2018 03:42:14 INFO 140118425614144] #progress_metric: host=algo-2, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 6, "sum": 6.0, "min": 6}, "Total Records Seen": {"count": 1, "max": 30000, "sum": 30000.0, "min": 30000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1530675734.083902, "Dimensions": {"Host": "algo-2", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 0}, "StartTime": 1530675733.749845}
#
# [07/04/2018 03:42:14 INFO 140118425614144] #throughput_metric: host=algo-2, train throughput=74810.650381 records/second
# [07/04/2018 03:42:14 INFO 140118425614144] shrinking 100 centers into 10
# [07/04/2018 03:42:14 INFO 140118425614144] local kmeans attempt #0. Current mean square distance 10.034799
# [07/04/2018 03:42:14 INFO 140118425614144] local kmeans attempt #1. Current mean square distance 10.609072
# [07/04/2018 03:42:14 INFO 140118425614144] local kmeans attempt #2. Current mean square distance 10.596355
# [07/04/2018 03:42:14 INFO 140118425614144] local kmeans attempt #3. Current mean square distance 10.480383
# [07/04/2018 03:42:14 INFO 140118425614144] local kmeans attempt #4. Current mean square distance 10.934847
# [07/04/2018 03:42:14 INFO 140118425614144] local kmeans attempt #5. Current mean square distance 10.550310
# [07/04/2018 03:42:14 INFO 140118425614144] local kmeans attempt #6. Current mean square distance 10.466156
# [07/04/2018 03:42:14 INFO 140118425614144] local kmeans attempt #7. Current mean square distance 10.492427
# [07/04/2018 03:42:14 INFO 140118425614144] local kmeans attempt #8. Current mean square distance 10.515285
# [07/04/2018 03:42:14 INFO 140118425614144] local kmeans attempt #9. Current mean square distance 10.549679
# [07/04/2018 03:42:14 INFO 140118425614144] finished shrinking process. Mean Square Distance = 10
# [07/04/2018 03:42:14 INFO 140118425614144] #quality_metric: host=algo-2, train msd <loss>=10.0347986221
# [07/04/2018 03:42:14 INFO 140118425614144] batch data loading with context took: 56.1463%, (0.187381 secs)
# [07/04/2018 03:42:14 INFO 140118425614144] compute all data-center distances: inner product took: 13.2479%, (0.044213 secs)
# [07/04/2018 03:42:14 INFO 140118425614144] compute all data-center distances: point norm took: 10.3894%, (0.034673 secs)
# [07/04/2018 03:42:14 INFO 140118425614144] predict compute msd took: 7.6279%, (0.025457 secs)
# [07/04/2018 03:42:14 INFO 140118425614144] collect from kv store took: 4.8847%, (0.016302 secs)
# [07/04/2018 03:42:14 INFO 140118425614144] gradient: cluster center took: 4.1643%, (0.013898 secs)
# [07/04/2018 03:42:14 INFO 140118425614144] gradient: cluster size  took: 0.9979%, (0.003330 secs)
# [07/04/2018 03:42:14 INFO 140118425614144] splitting centers key-value pair took: 0.8426%, (0.002812 secs)
# [07/04/2018 03:42:14 INFO 140118425614144] gradient: one_hot took: 0.8328%, (0.002779 secs)
# [07/04/2018 03:42:14 INFO 140118425614144] update state and report convergance took: 0.4177%, (0.001394 secs)
# [07/04/2018 03:42:14 INFO 140118425614144] compute all data-center distances: center norm took: 0.3574%, (0.001193 secs)
# [07/04/2018 03:42:14 INFO 140118425614144] update set-up time took: 0.0546%, (0.000182 secs)
# [07/04/2018 03:42:14 INFO 140118425614144] predict minus dist took: 0.0365%, (0.000122 secs)
# [07/04/2018 03:42:14 INFO 140118425614144] TOTAL took: 0.333737373352
# [07/04/2018 03:42:14 INFO 140118425614144] Number of GPUs being used: 0
# [07/04/2018 03:42:14 INFO 140118425614144] No model is serialized on a non-master node
# #metrics {"Metrics": {"finalize.time": {"count": 1, "max": 327.564001083374, "sum": 327.564001083374, "min": 327.564001083374}, "initialize.time": {"count": 1, "max": 12.511968612670898, "sum": 12.511968612670898, "min": 12.511968612670898}, "model.serialize.time": {"count": 1, "max": 0.1971721649169922, "sum": 0.1971721649169922, "min": 0.1971721649169922}, "update.time": {"count": 1, "max": 333.8580131530762, "sum": 333.8580131530762, "min": 333.8580131530762}, "epochs": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "state.serialize.time": {"count": 1, "max": 0.5650520324707031, "sum": 0.5650520324707031, "min": 0.5650520324707031}, "_shrink.time": {"count": 1, "max": 324.04208183288574, "sum": 324.04208183288574, "min": 324.04208183288574}}, "EndTime": 1530675734.412959, "Dimensions": {"Host": "algo-2", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1530675733.69424}
#
# [07/04/2018 03:42:14 INFO 140118425614144] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 2805.1750659942627, "sum": 2805.1750659942627, "min": 2805.1750659942627}, "setuptime": {"count": 1, "max": 519.9391841888428, "sum": 519.9391841888428, "min": 519.9391841888428}}, "EndTime": 1530675734.416995, "Dimensions": {"Host": "algo-2", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1530675734.413066}
# ===== Job Complete =====
# Billable seconds: 207
# CPU times: user 7.59 s, sys: 404 ms, total: 8 s
# Wall time: 4min 22s

# %%
# %%time
kmeans_predictor = kmeans.deploy(initial_instance_count=1,
                                 instance_type='ml.m4.xlarge')
# Out:
# INFO:sagemaker:Creating model with name: kmeans-2018-07-04-03-44-39-827
# INFO:sagemaker:Creating endpoint with name kmeans-2018-07-04-03-38-47-265
# --------------------------------------------------------------------------!CPU times: user 300 ms, sys: 16 ms, total: 316 ms
# Wall time: 6min 17s

# %%
result = kmeans_predictor.predict(valid_set[0][31:32])
print(result)
# Out:
# [label {
#   key: "closest_cluster"
#   value {
#     float32_tensor {
#       values: 0.0
#     }
#   }
# }
# label {
#   key: "distance_to_cluster"
#   value {
#     float32_tensor {
#       values: 5.401556968688965
#     }
#   }
# }
# ]

# %%
# %%time 

result = kmeans_predictor.predict(valid_set[0][0:100])
clusters = [r.label['closest_cluster'].float32_tensor.values[0] for r in result]
# Out:
# CPU times: user 20 ms, sys: 0 ns, total: 20 ms
# Wall time: 255 ms

# %%
for cluster in range(10):
    print('\n\n\nCluster {}:'.format(int(cluster)))
    digits = [ img for l, img in zip(clusters, valid_set[0]) if int(l) == cluster ]
    height=((len(digits)-1)//5)+1
    width=5
    plt.rcParams["figure.figsize"] = (width,height)
    _, subplots = plt.subplots(height, width)
    subplots=numpy.ndarray.flatten(subplots)
    for subplot, image in zip(subplots, digits):
        show_digit(image, subplot=subplot)
    for subplot in subplots[len(digits):]:
        subplot.axis('off')

    plt.show()
# Out:
# Cluster 0:
# Cluster 1:
# Cluster 2:
# Cluster 3:
# Cluster 4:
# Cluster 5:
# Cluster 6:
# Cluster 7:
# Cluster 8:
# Cluster 9:
